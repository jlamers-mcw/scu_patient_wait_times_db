# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import re
import warnings

from datetime import time, timedelta, datetime

warnings.filterwarnings('ignore', category=UserWarning, module='openpyxl')

# %% [markdown]
# # Cleaned Data
# - X Date
# - X Unique Patient ID
# - X Patient Tracker Order
# - X Version of Patient Tracker
# - X PCP or Specialtiy
# - X Language
# - Time: Time Arrived (Front Desk)
# - Time: Checkpoint Recieves Clipboard (Checkpoint)
# - Time: Student Doctor Receives Clipboard (Checkpoint)
# - Time: Student Doctor ready to staff / placed in queue for physician (Checkpoint)
# - Time: Physician Staffing Start (Checkpoint)
# - Time: Physician Staffing End (Checkpoint)
# - Time: Patient Checks Out (Front Desk)

# %%
patient_tracker_v1_end_date = "11.01.25"

# %%
#time_data_all = pd.DataFrame()

time_data_list = [] 

for patient_visit_tracker in sorted(os.listdir('./Data/SCU Patient Trackers/')):
    print(patient_visit_tracker)

    #############################################################################
    # Import data from patient visit tracker: checkpoint tracker table
    
    time_data = pd.read_excel(
        f"./Data/SCU Patient Trackers/{patient_visit_tracker}",
        sheet_name='Checkpoint Tracker (Checkpoint)',
        header=2
    )

    lang_data = pd.read_excel(
        f"./Data/SCU Patient Trackers/{patient_visit_tracker}",
        sheet_name='Intake Form Tracker (FrontDesk)',
        header=1
    )

    # Remove rows where BOTH Patient name AND DOB are empty/null
    time_data = time_data[~(time_data["Patient Name"].isna() & time_data['DOB'].isna())]

    # Remove rows where BOTH Patient name AND DOB are empty/null
    lang_data = lang_data[~(lang_data["Patient Name"].isna() & lang_data['DOB'].isna())]

    ############################################################################

    ############################################################################
    # Add language to time data
    
    lang_data["DOB"] = pd.to_datetime(
        lang_data["DOB"],
        errors='coerce'
    )

    time_data["DOB"] = pd.to_datetime(
        time_data["DOB"],
        errors='coerce'
    )

    #print(f"len of lang data: {len(lang_data)}")
    #print(f"len of time data pre merge: {len(time_data)}")

    #print(time_data)

    time_data = time_data.merge(
        lang_data[["DOB", "Patient Name", "Language"]], 
        on=["DOB", "Patient Name"], 
        how="left"
    )

    #print(f"len of time data post merge: {len(time_data)}")

    #print(time_data)
    #break
    
    ############################################################################
    
    ############################################################################
    # Adds the order in which the patient is listed in the tracker
    
    number_of_example_rows = (
        sum(
            ['Al Demo' in i for i in time_data['Patient Name'].dropna()]
        ) + 
        sum(
            ['Britney Spears ' in i for i in time_data['Patient Name'].dropna()]
        )
    )
    
    time_data = time_data[time_data['Patient Name'] != 'Al Demo']
    time_data = time_data[time_data['Patient Name'] != 'Britney Spears ']

    time_data["Patient Tracker Order"] = (
        time_data.index - number_of_example_rows
    )
    
    ############################################################################
    
    ############################################################################
    # Get the date from the file name and add it to each row
    match = re.search(r'\d{1,2}\.\d{1,2}\.\d{2,4}', patient_visit_tracker)
    if match:
        date_str = match.group()
        date = pd.to_datetime(date_str, format='%m.%d.%Y', errors='coerce')
        
        if pd.isna(date):  # Try 2-digit year format if 4-digit failed
            date = pd.to_datetime(date_str, format='%m.%d.%y')
    
        time_data["date"] = [ date ] * len(time_data)

        ###########################################################################
        # determine which version of the patient tracker is being used

        if date.date() <= datetime.strptime(patient_tracker_v1_end_date, "%m.%d.%y").date():
            time_data["Patient Tracker Version"] = "v1"
        else:
            time_data["Patient Tracker Version"] = "v2"

        ###########################################################################

    ############################################################################
    # give each patient a unique id that isn't name or dob to deidentify

    time_data["Unique ID"] = ""

    for i in time_data["Unique ID"].index:
        try:
            time_data.loc[i,"Unique ID"] = str(
                str(time_data.loc[i,"date"].date()) + str(time_data.loc[i,'DOB'])[2:4] + str(time_data.loc[i,"Patient Tracker Order"]) + str(time_data.loc[i,'Patient Name'])[-2::]
            )
        except Exception as e:
            pass
    ############################################################################
    
    # Append to list
    time_data_list.append(time_data)

# Concatenate all at once - pandas will handle column alignment automatically
time_data_all_raw = pd.concat(time_data_list, ignore_index=True)
# Out:
# Patient Visit Tracker (10.25.25).xlsx
# Patient Visit Tracker (11.01.25).xlsx
# Patient Visit Tracker (11.08.25).xlsx
# Patient Visit Tracker (11.15.25).xlsx
# Patient Visit Tracker (12.06.2025).xlsx
# Patient Visit Tracker (12.13.2025).xlsx
# Patient Visit Tracker - UPDATED (12.20.2025).xlsx
# Patient Visit Tracker 10.04.2025.xlsx
# Patient Visit Tracker 10.11.2025.xlsx
# Patient Visit Tracker 10.18.25.xlsx

# %%
time_pattern = r'^\d{2}:\d{2}:\d{2}$'

# Create a mask for rows that DON'T match the pattern
mask = ~time_data_all_raw["PCP or Specialty"].apply(lambda x: bool(re.match(time_pattern, str(x))))

# Keep only rows where the mask is True
time_data_all_raw = time_data_all_raw[mask]
time_data_all_raw.reset_index(inplace=True)

# %%
time_data_all_clean = time_data_all_raw[[
    "date",
    "Unique ID",
    "Patient Tracker Order",
    "Patient Tracker Version",
    'PCP or Specialty',
    'Language'
]]

# %%
time_col_to_clean = [
    'Time: Time Arrived (Front Desk)',
    'Time: Checkpoint Recieves Clipboard (Checkpoint)',
    'Time: Student Doctor Receives Clipboard (Checkpoint)',
    'Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)',
    "Time: Physician Staffing Start (Checkpoint)",
    'Time: Physician Staffing End (Checkpoint)',
    "Time: Patient Checks Out (Front Desk)"
]

# Make an explicit copy if time_data_all_clean is a slice
time_data_all_clean = time_data_all_clean.copy()

for col_to_clean in time_col_to_clean:
    # Clean times that were entered wrong in excel
    for i in range(len(time_data_all_raw[col_to_clean])):
        if type(time_data_all_raw.loc[i, col_to_clean]) is str:
            # Found issue 1
            # Example 9:40AM should be 09:40:00
            time_data_all_raw.loc[i, col_to_clean] = re.sub(
                r'(:\d{2})[a-zA-Z]{2}',  # pattern: lowercase letters
                r'\1:00',  # replacement: empty string (removes the letters)
                time_data_all_raw.loc[i, col_to_clean]  # string to operate on
            )

    
    # Convert to datetime
    time_data_all_clean[col_to_clean] = pd.to_datetime(
        time_data_all_raw['date'].astype(str) + ' ' + time_data_all_raw[col_to_clean].astype(str),
        format='%Y-%m-%d %H:%M:%S',
        errors='coerce'
    )
    
    # Converts non-military to military time
    # Use boolean indexing instead of iterating
    mask = (
        pd.notna(time_data_all_clean[col_to_clean]) &
        (time_data_all_clean[col_to_clean].dt.time < time(7, 30))
    )
    time_data_all_clean.loc[mask, col_to_clean] += timedelta(hours=12)

# %%
time_data_all_clean['Canceled'] = time_data_all_clean[time_col_to_clean].isna().all(axis=1)

#Fixing colum order so canceled appears before time
cols = time_data_all_clean.columns.tolist()
cols = cols[:6] + cols[-1:] + cols[6:-1]

time_data_all_clean = time_data_all_clean[cols]

# %%
time_data_all_clean
# Out:
#           date         Unique ID  Patient Tracker Order  \
# 0   2025-10-25   2025-10-25760B.                      0
# 1   2025-10-25   2025-10-25921H.                      1
# 2   2025-10-25   2025-10-25642S.                      2
# 3   2025-10-25   2025-10-25543T.                      3
# 4   2025-10-25   2025-10-25024A.                      4
# ..         ...               ...                    ...
# 145 2025-10-18  2025-10-187216an                     16
# 146 2025-10-18  2025-10-185917an                     17
# 147 2025-10-18  2025-10-186518na                     18
# 148 2025-10-18  2025-10-189519an                     19
# 149 2025-10-18  2025-10-187720la                     20
#
#     Patient Tracker Version PCP or Specialty  Language  Canceled  \
# 0                        v1              PCP   English      True
# 1                        v1              PCP   English     False
# 2                        v1              PCP  Ukranian     False
# 3                        v1              PCP   English     False
# 4                        v1              PCP   English     False
# ..                      ...              ...       ...       ...
# 145                      v1              PCP   English     False
# 146                      v1              PCP   Spanish     False
# 147                      v1              PCP   Russian     False
# 148                      v1              PCP   English     False
# 149                      v1              PCP   Spanish      True
#
#     Time: Time Arrived (Front Desk)  \
# 0                               NaT
# 1               2025-10-25 08:30:00
# 2               2025-10-25 09:00:00
# 3               2025-10-25 10:05:00
# 4               2025-10-25 10:10:00
# ..                              ...
# 145             2025-10-18 10:11:00
# 146             2025-10-18 10:15:00
# 147             2025-10-18 10:10:00
# 148             2025-10-18 10:25:00
# 149                             NaT
#
#     Time: Checkpoint Recieves Clipboard (Checkpoint)  \
# 0                                                NaT
# 1                                2025-10-25 08:56:00
# 2                                2025-10-25 09:40:00
# 3                                2025-10-25 10:48:00
# 4                                2025-10-25 10:40:00
# ..                                               ...
# 145                              2025-10-18 10:21:00
# 146                              2025-10-18 10:43:00
# 147                              2025-10-18 10:21:00
# 148                              2025-10-18 10:39:00
# 149                                              NaT
#
#     Time: Student Doctor Receives Clipboard (Checkpoint)  \
# 0                                                  NaT
# 1                                                  NaT
# 2                                                  NaT
# 3                                                  NaT
# 4                                                  NaT
# ..                                                 ...
# 145                                                NaT
# 146                                                NaT
# 147                                                NaT
# 148                                                NaT
# 149                                                NaT
#
#     Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)  \
# 0                                                  NaT
# 1                                  2025-10-25 09:19:00
# 2                                  2025-10-25 10:06:00
# 3                                  2025-10-25 11:40:00
# 4                                  2025-10-25 11:05:00
# ..                                                 ...
# 145                                2025-10-18 10:55:00
# 146                                2025-10-18 11:40:00
# 147                                2025-10-18 10:56:00
# 148                                2025-10-18 11:15:00
# 149                                                NaT
#
#     Time: Physician Staffing Start (Checkpoint)  \
# 0                                           NaT
# 1                           2025-10-25 09:45:00
# 2                           2025-10-25 10:30:00
# 3                           2025-10-25 12:17:00
# 4                           2025-10-25 11:20:00
# ..                                          ...
# 145                         2025-10-18 11:30:00
# 146                         2025-10-18 12:00:00
# 147                         2025-10-18 11:00:00
# 148                         2025-10-18 11:30:00
# 149                                         NaT
#
#     Time: Physician Staffing End (Checkpoint)  \
# 0                                         NaT
# 1                                         NaT
# 2                                         NaT
# 3                                         NaT
# 4                                         NaT
# ..                                        ...
# 145                                       NaT
# 146                                       NaT
# 147                                       NaT
# 148                                       NaT
# 149                                       NaT
#
#     Time: Patient Checks Out (Front Desk)
# 0                                     NaT
# 1                     2025-10-25 11:15:00
# 2                     2025-10-25 11:30:00
# 3                     2025-10-25 14:12:00
# 4                     2025-10-25 12:08:00
# ..                                    ...
# 145                   2025-10-18 13:32:00
# 146                   2025-10-18 14:11:00
# 147                                   NaT
# 148                   2025-10-18 12:00:00
# 149                                   NaT
#
# [150 rows x 14 columns]

# %%
time_data_all_clean.to_csv("patient_visit_tracker.csv")

# %% [markdown]
# # Future cleaning
# - patient visit tracker 10.11.2025
#    - has a bunch of random patients at the bottom of tracker not sure why pt 10 - 19

# %% [markdown]
# # Verifying Cleaning

# %% [markdown]
# ## Future tests

# %% [markdown]
# ## Tests

# %%
# Check if all rows have at least three non na values
pass_check = True

rows_that_fail_this_check = []

for i, row in time_data_all_clean.iterrows():
    if row[time_col_to_clean].notna().sum() < 3 and not row["Canceled"]:
        pass_check = False
        rows_that_fail_this_check.append(row) 
        print(row)        

print(
    f"All rows have atleast three non na values: {pass_check}\nPercent that fail this test: {len(rows_that_fail_this_check) / len(time_data_all_clean) * 100}%"
)
# Out:
# date                                                                                  2025-10-04 00:00:00
# Unique ID                                                                                 2025-10-04965ve
# Patient Tracker Order                                                                                   5
# Patient Tracker Version                                                                                v1
# PCP or Specialty                                                                                     Derm
# Language                                                                                          English
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-10-04 09:09:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                                  NaT
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)                    NaT
# Time: Physician Staffing Start (Checkpoint)                                                           NaT
# Time: Physician Staffing End (Checkpoint)                                                             NaT
# Time: Patient Checks Out (Front Desk)                                                 2025-10-04 11:48:00
# Name: 105, dtype: object
# date                                                                                  2025-10-04 00:00:00
# Unique ID                                                                                 2025-10-04648va
# Patient Tracker Order                                                                                   8
# Patient Tracker Version                                                                                v1
# PCP or Specialty                                                                                     Derm
# Language                                                                                          English
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-10-04 09:34:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                                  NaT
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)                    NaT
# Time: Physician Staffing Start (Checkpoint)                                                           NaT
# Time: Physician Staffing End (Checkpoint)                                                             NaT
# Time: Patient Checks Out (Front Desk)                                                 2025-10-04 12:39:00
# Name: 108, dtype: object
# date                                                                                  2025-10-04 00:00:00
# Unique ID                                                                                 2025-10-04049ly
# Patient Tracker Order                                                                                   9
# Patient Tracker Version                                                                                v1
# PCP or Specialty                                                                                     Derm
# Language                                                                                          English
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-10-04 09:42:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                                  NaT
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)                    NaT
# Time: Physician Staffing Start (Checkpoint)                                                           NaT
# Time: Physician Staffing End (Checkpoint)                                                             NaT
# Time: Patient Checks Out (Front Desk)                                                                 NaT
# Name: 109, dtype: object
# date                                                                                  2025-10-18 00:00:00
# Unique ID                                                                                 2025-10-18736ez
# Patient Tracker Order                                                                                   6
# Patient Tracker Version                                                                                v1
# PCP or Specialty                                                                            PCP (Vaccine)
# Language                                                                                  English/Spanish
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-10-18 08:08:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                                  NaT
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)                    NaT
# Time: Physician Staffing Start (Checkpoint)                                                           NaT
# Time: Physician Staffing End (Checkpoint)                                                             NaT
# Time: Patient Checks Out (Front Desk)                                                 2025-10-18 09:48:00
# Name: 135, dtype: object
# All rows have atleast three non na values: False
# Percent that fail this test: 2.666666666666667%

# %%
# Check if all rows that canceled have a PCP and language
pass_check = True

rows_that_fail_this_check = []

for i, row in time_data_all_clean.iterrows():
    if pd.isna(row["Language"]) and pd.isna(row["PCP or Specialty"]):
        pass_check = False
        rows_that_fail_this_check.append(row) 
        print(row)        

print(
    f"All canceled rows have a Language and PCP: {pass_check}\nPercent that fail this test: {len(rows_that_fail_this_check) / len(time_data_all_clean) * 100}%"
)
# Out:
# date                                                                                  2025-10-18 00:00:00
# Unique ID                                                                                  2025-10-18T0on
# Patient Tracker Order                                                                                   0
# Patient Tracker Version                                                                                v1
# PCP or Specialty                                                                                      NaN
# Language                                                                                              NaN
# Canceled                                                                                             True
# Time: Time Arrived (Front Desk)                                                                       NaT
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                                  NaT
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)                    NaT
# Time: Physician Staffing Start (Checkpoint)                                                           NaT
# Time: Physician Staffing End (Checkpoint)                                                             NaT
# Time: Patient Checks Out (Front Desk)                                                                 NaT
# Name: 129, dtype: object
# All canceled rows have a Language and PCP: False
# Percent that fail this test: 0.6666666666666667%

# %%
# Check if all rows that canceled have a PCP and language
pass_check = True

rows_that_fail_this_check = []

for i, row in time_data_all_clean.iterrows():
    if any(char.isdigit() for char in str(row["PCP or Specialty"])):
        pass_check = False
        rows_that_fail_this_check.append(row) 
        print(row)        

print(
    f"All canceled rows have a Language and PCP: {pass_check}\nPercent that fail this test: {len(rows_that_fail_this_check) / len(time_data_all_clean) * 100}%"
)
# Out:
# date                                                                                  2025-11-15 00:00:00
# Unique ID                                                                                 2025-11-15700is
# Patient Tracker Order                                                                                   0
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                       G2
# Language                                                                                          English
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-11-15 08:33:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                  2025-11-15 11:05:00
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)    2025-11-15 11:26:00
# Time: Physician Staffing Start (Checkpoint)                                           2025-11-15 12:38:00
# Time: Physician Staffing End (Checkpoint)                                             2025-11-15 12:52:00
# Time: Patient Checks Out (Front Desk)                                                 2025-11-15 13:34:00
# Name: 37, dtype: object
# date                                                                                  2025-11-15 00:00:00
# Unique ID                                                                                 2025-11-15671on
# Patient Tracker Order                                                                                   1
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                       R1
# Language                                                                                          English
# Canceled                                                                                             True
# Time: Time Arrived (Front Desk)                                                                       NaT
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                                  NaT
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)                    NaT
# Time: Physician Staffing Start (Checkpoint)                                                           NaT
# Time: Physician Staffing End (Checkpoint)                                                             NaT
# Time: Patient Checks Out (Front Desk)                                                                 NaT
# Name: 38, dtype: object
# date                                                                                  2025-11-15 00:00:00
# Unique ID                                                                                 2025-11-15622lo
# Patient Tracker Order                                                                                   2
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                       R2
# Language                                                                                          English
# Canceled                                                                                             True
# Time: Time Arrived (Front Desk)                                                                       NaT
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                                  NaT
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)                    NaT
# Time: Physician Staffing Start (Checkpoint)                                                           NaT
# Time: Physician Staffing End (Checkpoint)                                                             NaT
# Time: Patient Checks Out (Front Desk)                                                                 NaT
# Name: 39, dtype: object
# date                                                                                  2025-11-15 00:00:00
# Unique ID                                                                                 2025-11-15673on
# Patient Tracker Order                                                                                   3
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                       G6
# Language                                                                                          English
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-11-15 08:08:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                  2025-11-15 08:28:00
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)                    NaT
# Time: Physician Staffing Start (Checkpoint)                                                           NaT
# Time: Physician Staffing End (Checkpoint)                                                             NaT
# Time: Patient Checks Out (Front Desk)                                                 2025-11-15 11:30:00
# Name: 40, dtype: object
# date                                                                                  2025-11-15 00:00:00
# Unique ID                                                                                 2025-11-15724kh
# Patient Tracker Order                                                                                   4
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                       R3
# Language                                                                                              NaN
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-11-15 08:45:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                  2025-11-15 09:12:00
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)    2025-11-15 09:39:00
# Time: Physician Staffing Start (Checkpoint)                                           2025-11-15 09:42:00
# Time: Physician Staffing End (Checkpoint)                                             2025-11-15 09:59:00
# Time: Patient Checks Out (Front Desk)                                                 2025-11-15 10:15:00
# Name: 41, dtype: object
# date                                                                                  2025-11-15 00:00:00
# Unique ID                                                                                 2025-11-15745ez
# Patient Tracker Order                                                                                   5
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                       G5
# Language                                                                                          English
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-11-15 08:38:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                  2025-11-15 08:54:00
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)                    NaT
# Time: Physician Staffing Start (Checkpoint)                                                           NaT
# Time: Physician Staffing End (Checkpoint)                                                             NaT
# Time: Patient Checks Out (Front Desk)                                                 2025-11-15 11:27:00
# Name: 42, dtype: object
# date                                                                                  2025-11-15 00:00:00
# Unique ID                                                                                 2025-11-15046ez
# Patient Tracker Order                                                                                   6
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                       P1
# Language                                                                                              NaN
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-11-15 09:18:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                  2025-11-15 10:22:00
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)    2025-11-15 11:02:00
# Time: Physician Staffing Start (Checkpoint)                                           2025-11-15 11:15:00
# Time: Physician Staffing End (Checkpoint)                                             2025-11-15 11:36:00
# Time: Patient Checks Out (Front Desk)                                                 2025-11-15 12:37:00
# Name: 43, dtype: object
# date                                                                                  2025-11-15 00:00:00
# Unique ID                                                                                 2025-11-15817jo
# Patient Tracker Order                                                                                   7
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                       G3
# Language                                                                                          Spanish
# Canceled                                                                                             True
# Time: Time Arrived (Front Desk)                                                                       NaT
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                                  NaT
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)                    NaT
# Time: Physician Staffing Start (Checkpoint)                                                           NaT
# Time: Physician Staffing End (Checkpoint)                                                             NaT
# Time: Patient Checks Out (Front Desk)                                                                 NaT
# Name: 44, dtype: object
# date                                                                                  2025-11-15 00:00:00
# Unique ID                                                                                 2025-11-15918s
# Patient Tracker Order                                                                                   8
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                       P6
# Language                                                                                          English
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-11-15 09:07:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                  2025-11-15 09:23:00
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)                    NaT
# Time: Physician Staffing Start (Checkpoint)                                                           NaT
# Time: Physician Staffing End (Checkpoint)                                                             NaT
# Time: Patient Checks Out (Front Desk)                                                 2025-11-15 11:50:00
# Name: 45, dtype: object
# date                                                                                  2025-11-15 00:00:00
# Unique ID                                                                                 2025-11-15739ls
# Patient Tracker Order                                                                                   9
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                       G1
# Language                                                                                          English
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-11-15 09:40:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                  2025-11-15 10:20:00
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)                    NaT
# Time: Physician Staffing Start (Checkpoint)                                                           NaT
# Time: Physician Staffing End (Checkpoint)                                                             NaT
# Time: Patient Checks Out (Front Desk)                                                 2025-11-15 11:49:00
# Name: 46, dtype: object
# date                                                                                  2025-11-15 00:00:00
# Unique ID                                                                                2025-11-157510on
# Patient Tracker Order                                                                                  10
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                       P5
# Language                                                                                          English
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-11-15 09:48:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                  2025-11-15 10:03:00
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)                    NaT
# Time: Physician Staffing Start (Checkpoint)                                                           NaT
# Time: Physician Staffing End (Checkpoint)                                                             NaT
# Time: Patient Checks Out (Front Desk)                                                 2025-11-15 12:35:00
# Name: 47, dtype: object
# date                                                                                  2025-11-15 00:00:00
# Unique ID                                                                                2025-11-155911an
# Patient Tracker Order                                                                                  11
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                       R4
# Language                                                                                          Spanish
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-11-15 10:15:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                  2025-11-15 10:47:00
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)    2025-11-15 11:22:00
# Time: Physician Staffing Start (Checkpoint)                                           2025-11-15 11:59:00
# Time: Physician Staffing End (Checkpoint)                                             2025-11-15 12:35:00
# Time: Patient Checks Out (Front Desk)                                                 2025-11-15 13:25:00
# Name: 48, dtype: object
# date                                                                                  2025-11-15 00:00:00
# Unique ID                                                                                2025-11-158212ck
# Patient Tracker Order                                                                                  12
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                       P4
# Language                                                                                          English
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-11-15 10:30:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                  2025-11-15 10:51:00
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)                    NaT
# Time: Physician Staffing Start (Checkpoint)                                                           NaT
# Time: Physician Staffing End (Checkpoint)                                                             NaT
# Time: Patient Checks Out (Front Desk)                                                 2025-11-15 12:38:00
# Name: 49, dtype: object
# date                                                                                  2025-11-15 00:00:00
# Unique ID                                                                                2025-11-159413on
# Patient Tracker Order                                                                                  13
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                       B6
# Language                                                                                          English
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-11-15 10:33:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                  2025-11-15 10:59:00
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)                    NaT
# Time: Physician Staffing Start (Checkpoint)                                                           NaT
# Time: Physician Staffing End (Checkpoint)                                                             NaT
# Time: Patient Checks Out (Front Desk)                                                 2025-11-15 13:08:00
# Name: 50, dtype: object
# date                                                                                  2025-11-15 00:00:00
# Unique ID                                                                                2025-11-159714on
# Patient Tracker Order                                                                                  14
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                       R5
# Language                                                                                              NaN
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-11-15 09:59:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                  2025-11-15 10:50:00
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)    2025-11-15 11:13:00
# Time: Physician Staffing Start (Checkpoint)                                           2025-11-15 11:36:00
# Time: Physician Staffing End (Checkpoint)                                             2025-11-15 11:59:00
# Time: Patient Checks Out (Front Desk)                                                 2025-11-15 13:01:00
# Name: 51, dtype: object
# date                                                                                  2025-11-15 00:00:00
# Unique ID                                                                                2025-11-159715ha
# Patient Tracker Order                                                                                  15
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                       R6
# Language                                                                                              NaN
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-11-15 10:43:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                  2025-11-15 11:08:00
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)    2025-11-15 11:38:00
# Time: Physician Staffing Start (Checkpoint)                                           2025-11-15 12:54:00
# Time: Physician Staffing End (Checkpoint)                                             2025-11-15 13:06:00
# Time: Patient Checks Out (Front Desk)                                                 2025-11-15 13:14:00
# Name: 52, dtype: object
# date                                                                                  2025-11-15 00:00:00
# Unique ID                                                                                2025-11-150216ah
# Patient Tracker Order                                                                                  16
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                       B5
# Language                                                                                              NaN
# Canceled                                                                                             True
# Time: Time Arrived (Front Desk)                                                                       NaT
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                                  NaT
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)                    NaT
# Time: Physician Staffing Start (Checkpoint)                                                           NaT
# Time: Physician Staffing End (Checkpoint)                                                             NaT
# Time: Patient Checks Out (Front Desk)                                                                 NaT
# Name: 53, dtype: object
# date                                                                                  2025-11-15 00:00:00
# Unique ID                                                                                2025-11-157517ey
# Patient Tracker Order                                                                                  17
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                       R1
# Language                                                                                              NaN
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-11-15 08:57:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                                      NaT
# Time: Student Doctor Receives Clipboard (Checkpoint)                                  2025-11-15 09:27:00
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)    2025-11-15 09:44:00
# Time: Physician Staffing Start (Checkpoint)                                           2025-11-15 10:00:00
# Time: Physician Staffing End (Checkpoint)                                             2025-11-15 10:13:00
# Time: Patient Checks Out (Front Desk)                                                 2025-11-15 11:30:00
# Name: 54, dtype: object
# All canceled rows have a Language and PCP: False
# Percent that fail this test: 12.0%

# %%
# Check if all time is less than six hours
pass_check = True

for i, row in time_data_all_clean.iterrows():
    if (row["Time: Patient Checks Out (Front Desk)"] - row["Time: Time Arrived (Front Desk)"]).total_seconds() > 6*60*60:
        pass_check = False
        print(row)        

print(
    f"All visit times are less than six hours: {pass_check}"
)
# Out:
# All visit times are less than six hours: True

# %%
# Check a that all total time is positive
pass_check = True

for i, row in time_data_all_clean.iterrows():
    if (row["Time: Patient Checks Out (Front Desk)"] - row["Time: Time Arrived (Front Desk)"]).total_seconds() < 0:
        pass_check = False
        print(row)        

print(
    f"All visit times are positive: {pass_check}"
)
# Out:
# All visit times are positive: True

# %%
# Test if all the differences are positive
pass_pos_val_check = [ True ] * ( len(time_col_to_clean) - 1 )

for test_in in range(len(time_col_to_clean)):
    if test_in > 0:

        print(f"\nTEST: All visit {time_col_to_clean[test_in - 1]} to {time_col_to_clean[test_in]} are positive\n")
    
        for i, row in time_data_all_clean.iterrows():
            if (row[time_col_to_clean[test_in]] - row[time_col_to_clean[test_in - 1]]).total_seconds() < 0:
                pass_pos_val_check[test_in - 1] = False
                print(row)   

        print(f"\nTEST result: {pass_pos_val_check[test_in - 1]}")

print(f"\nThe percent of differences that pass this check: {sum(pass_pos_val_check) / len(pass_pos_val_check) * 100}%")
# Out:
# TEST: All visit Time: Time Arrived (Front Desk) to Time: Checkpoint Recieves Clipboard (Checkpoint) are positive
#
# date                                                                                  2025-12-06 00:00:00
# Unique ID                                                                                2025-12-067311iz
# Patient Tracker Order                                                                                  11
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                      PCP
# Language                                                                               Spanish, Castilian
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-12-06 10:50:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                      2025-12-06 10:46:00
# Time: Student Doctor Receives Clipboard (Checkpoint)                                  2025-12-06 10:50:00
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)    2025-12-06 11:44:00
# Time: Physician Staffing Start (Checkpoint)                                           2025-12-06 12:00:00
# Time: Physician Staffing End (Checkpoint)                                             2025-12-06 13:05:00
# Time: Patient Checks Out (Front Desk)                                                 2025-12-06 13:10:00
# Name: 66, dtype: object
# date                                                                                  2025-12-13 00:00:00
# Unique ID                                                                                 2025-12-13036no
# Patient Tracker Order                                                                                   6
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                      PCP
# Language                                                                                          English
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-12-13 10:47:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                      2025-12-13 10:10:00
# Time: Student Doctor Receives Clipboard (Checkpoint)                                  2025-12-13 10:15:00
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)    2025-12-13 11:31:00
# Time: Physician Staffing Start (Checkpoint)                                           2025-12-13 12:20:00
# Time: Physician Staffing End (Checkpoint)                                             2025-12-13 12:40:00
# Time: Patient Checks Out (Front Desk)                                                 2025-12-13 12:51:00
# Name: 75, dtype: object
#
# TEST result: False
#
# TEST: All visit Time: Checkpoint Recieves Clipboard (Checkpoint) to Time: Student Doctor Receives Clipboard (Checkpoint) are positive
#
#
# TEST result: True
#
# TEST: All visit Time: Student Doctor Receives Clipboard (Checkpoint) to Time: Student Doctor ready to staff / placed in queue for physician
# (Checkpoint) are positive
#
# date                                                                                  2025-12-06 00:00:00
# Unique ID                                                                                 2025-12-06639ms
# Patient Tracker Order                                                                                   9
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                      CCT
# Language                                                                                          English
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-12-06 10:17:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                      2025-12-06 10:27:00
# Time: Student Doctor Receives Clipboard (Checkpoint)                                  2025-12-06 10:29:00
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)    2025-12-06 08:50:00
# Time: Physician Staffing Start (Checkpoint)                                           2025-12-06 08:50:00
# Time: Physician Staffing End (Checkpoint)                                             2025-12-06 11:10:00
# Time: Patient Checks Out (Front Desk)                                                 2025-12-06 11:19:00
# Name: 64, dtype: object
#
# TEST result: False
#
# TEST: All visit Time: Student Doctor ready to staff / placed in queue for physician
# (Checkpoint) to Time: Physician Staffing Start (Checkpoint) are positive
#
# date                                                                                  2025-12-06 00:00:00
# Unique ID                                                                                 2025-12-06943du
# Patient Tracker Order                                                                                   3
# Patient Tracker Version                                                                                v2
# PCP or Specialty                                                                                 Derm&PCP
# Language                                                                                          English
# Canceled                                                                                            False
# Time: Time Arrived (Front Desk)                                                       2025-12-06 09:00:00
# Time: Checkpoint Recieves Clipboard (Checkpoint)                                      2025-12-06 09:30:00
# Time: Student Doctor Receives Clipboard (Checkpoint)                                  2025-12-06 10:50:00
# Time: Student Doctor ready to staff / placed in queue for physician \n(Checkpoint)    2025-12-06 11:40:00
# Time: Physician Staffing Start (Checkpoint)                                           2025-12-06 11:38:00
# Time: Physician Staffing End (Checkpoint)                                             2025-12-06 13:10:00
# Time: Patient Checks Out (Front Desk)                                                 2025-12-06 13:16:00
# Name: 58, dtype: object
#
# TEST result: False
#
# TEST: All visit Time: Physician Staffing Start (Checkpoint) to Time: Physician Staffing End (Checkpoint) are positive
#
#
# TEST result: True
#
# TEST: All visit Time: Physician Staffing End (Checkpoint) to Time: Patient Checks Out (Front Desk) are positive
#
#
# TEST result: True
#
# The percent of differences that pass this check: 50.0%

# %% [markdown]
# ## Distributions

# %%
for i in time_col_to_clean[1::]:
    print(f"\n{i}:")
    print(((time_data_all_clean[i] - time_data_all_clean['Time: Time Arrived (Front Desk)']).dropna().dt.total_seconds() / 60).describe())
# Out:
# Time: Checkpoint Recieves Clipboard (Checkpoint):
# count    91.000000
# mean     19.945055
# std      11.020549
# min     -37.000000
# 25%      14.000000
# 50%      19.000000
# 75%      26.000000
# max      50.000000
# dtype: float64
#
# Time: Student Doctor Receives Clipboard (Checkpoint):
# count     53.000000
# mean      28.773585
# std       24.905700
# min      -32.000000
# 25%       19.000000
# 50%       25.000000
# 75%       30.000000
# max      152.000000
# dtype: float64
#
# Time: Student Doctor ready to staff / placed in queue for physician
# (Checkpoint):
# count     83.000000
# mean      63.927711
# std       30.067316
# min      -87.000000
# 25%       49.000000
# 50%       62.000000
# 75%       78.000000
# max      173.000000
# dtype: float64
#
# Time: Physician Staffing Start (Checkpoint):
# count     83.000000
# mean      86.120482
# std       39.805747
# min      -87.000000
# 25%       56.500000
# 50%       86.000000
# 75%      109.500000
# max      245.000000
# dtype: float64
#
# Time: Physician Staffing End (Checkpoint):
# count     41.00000
# mean     116.04878
# std       44.81738
# min       53.00000
# 25%       93.00000
# 50%      110.00000
# 75%      135.00000
# max      259.00000
# dtype: float64
#
# Time: Patient Checks Out (Front Desk):
# count    106.000000
# mean     169.367925
# std       52.395806
# min       34.000000
# 25%      129.250000
# 50%      159.500000
# 75%      202.750000
# max      301.000000
# dtype: float64
